# %%
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt

# %%
root_dir = './Output/Sensitivity/'
runs = os.listdir(root_dir)
print(runs)

df_res = pd.DataFrame()

for run in runs:
    print(root_dir, run, '/Clustering/ClusterSummary.txt')
    file_path = f'{root_dir}{run}/Clustering/ClusterSummary.txt'

    
    
    df = pd.read_csv(file_path, sep='\: ')
    df = df.T
    df.columns = df.iloc[0]
    df = df[1:]
    df['T-val'] = run.replace('Run-', '')
    
    df_res = pd.concat([df_res, df])


df_res
# Out:
# ['Run-0.5', 'Run-0.75', 'Run-1.0', 'Run-1.25', 'Run-1.5', 'Run-1.75', 'Run-2.0', 'Run-2.25', 'Run-2.5']
# ./Output/Sensitivity/ Run-0.5 /Clustering/ClusterSummary.txt
# ./Output/Sensitivity/ Run-0.75 /Clustering/ClusterSummary.txt
# ./Output/Sensitivity/ Run-1.0 /Clustering/ClusterSummary.txt
# ./Output/Sensitivity/ Run-1.25 /Clustering/ClusterSummary.txt
# ./Output/Sensitivity/ Run-1.5 /Clustering/ClusterSummary.txt
# ./Output/Sensitivity/ Run-1.75 /Clustering/ClusterSummary.txt
# ./Output/Sensitivity/ Run-2.0 /Clustering/ClusterSummary.txt
# ./Output/Sensitivity/ Run-2.25 /Clustering/ClusterSummary.txt
# ./Output/Sensitivity/ Run-2.5 /Clustering/ClusterSummary.txt
# c:\Users\b01297ar\Documents\ProstateMRL-local\ProstateMRL-Radiomics\envPR\lib\site-packages\ipykernel_launcher.py:13: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   del sys.path[0]
# Mean number of stable clusters per patient Mean number of clusters per patient  \
# 4.75                                                                     35.75
# 7.05                                                                      27.8
# 7.75                                                                     25.15
# 8.45                                                                      23.8
# 9.2                                                                      20.35
# 9.45                                                                     19.55
# 9.1                                                                      20.95
# 8.9                                                                      21.25
# 9.4                                                                      19.25
#
# Mean number of stable clusters per patient Mean features per cluster per patient  \
# 4.75                                                          2.0601272664862695
# 7.05                                                            2.66260615471485
# 7.75                                                           2.972241565246967
# 8.45                                                           3.129117267384941
# 9.2                                                            3.674002305303501
# 9.45                                                           3.833822122150295
# 9.1                                                            3.636079137225182
# 8.9                                                             3.56069784002462
# 9.4                                                            3.882767846188899
#
# Mean number of stable clusters per patient Std features per cluster per patient  \
# 4.75                                                        0.32849236431103307
# 7.05                                                        0.46756874505081725
# 7.75                                                         0.5988744175233447
# 8.45                                                         0.5980229246407355
# 9.2                                                          0.6895504230737847
# 9.45                                                         0.7328435914942792
# 9.1                                                          0.8299138998177549
# 8.9                                                          0.7974961659386226
# 9.4                                                          0.7726262010239815
#
# Mean number of stable clusters per patient Range of clusters  \
# 4.75                                                   25 45
# 7.05                                                   20 36
# 7.75                                                   18 32
# 8.45                                                   16 31
# 9.2                                                    15 31
# 9.45                                                   14 30
# 9.1                                                    15 29
# 8.9                                                    14 31
# 9.4                                                    13 27
#
# Mean number of stable clusters per patient     Std of clusters  \
# 4.75                                         5.369259480451755
# 7.05                                         4.629425336623156
# 7.75                                         4.891184336183448
# 8.45                                         4.431941477857971
# 9.2                                          4.307582054690861
# 9.45                                          4.37065573786673
# 9.1                                          5.335827267779472
# 8.9                                          4.982865377312641
# 9.4                                         3.8371453204858317
#
# Mean number of stable clusters per patient         Range of features per cluster  \
# 4.75                                                                    1.6 2.88
# 7.05                                                                     2.0 3.6
# 7.75                                                                    2.25 4.0
# 8.45                                                      2.3225806451612905 4.5
# 9.2                                                       2.3225806451612905 4.8
# 9.45                                                       2.4 5.142857142857143
# 9.1                                                       2.4827586206896552 4.8
# 8.9                                         2.3225806451612905 5.142857142857143
# 9.4                                         2.6666666666666665 5.538461538461538
#
# Mean number of stable clusters per patient T-val
# 4.75                                         0.5
# 7.05                                        0.75
# 7.75                                         1.0
# 8.45                                        1.25
# 9.2                                          1.5
# 9.45                                        1.75
# 9.1                                          2.0
# 8.9                                         2.25
# 9.4                                          2.5

# %%
# make t-val first col

cols = df_res.columns.tolist()

cols = cols[-1:] + cols[:-1]
df_res = df_res[cols]

df_res
# Out:
# Mean number of stable clusters per patient T-val  \
# 4.75                                         0.5
# 7.05                                        0.75
# 7.75                                         1.0
# 8.45                                        1.25
# 9.2                                          1.5
# 9.45                                        1.75
# 9.1                                          2.0
# 8.9                                         2.25
# 9.4                                          2.5
#
# Mean number of stable clusters per patient Mean number of clusters per patient  \
# 4.75                                                                     35.75
# 7.05                                                                      27.8
# 7.75                                                                     25.15
# 8.45                                                                      23.8
# 9.2                                                                      20.35
# 9.45                                                                     19.55
# 9.1                                                                      20.95
# 8.9                                                                      21.25
# 9.4                                                                      19.25
#
# Mean number of stable clusters per patient Mean features per cluster per patient  \
# 4.75                                                          2.0601272664862695
# 7.05                                                            2.66260615471485
# 7.75                                                           2.972241565246967
# 8.45                                                           3.129117267384941
# 9.2                                                            3.674002305303501
# 9.45                                                           3.833822122150295
# 9.1                                                            3.636079137225182
# 8.9                                                             3.56069784002462
# 9.4                                                            3.882767846188899
#
# Mean number of stable clusters per patient Std features per cluster per patient  \
# 4.75                                                        0.32849236431103307
# 7.05                                                        0.46756874505081725
# 7.75                                                         0.5988744175233447
# 8.45                                                         0.5980229246407355
# 9.2                                                          0.6895504230737847
# 9.45                                                         0.7328435914942792
# 9.1                                                          0.8299138998177549
# 8.9                                                          0.7974961659386226
# 9.4                                                          0.7726262010239815
#
# Mean number of stable clusters per patient Range of clusters  \
# 4.75                                                   25 45
# 7.05                                                   20 36
# 7.75                                                   18 32
# 8.45                                                   16 31
# 9.2                                                    15 31
# 9.45                                                   14 30
# 9.1                                                    15 29
# 8.9                                                    14 31
# 9.4                                                    13 27
#
# Mean number of stable clusters per patient     Std of clusters  \
# 4.75                                         5.369259480451755
# 7.05                                         4.629425336623156
# 7.75                                         4.891184336183448
# 8.45                                         4.431941477857971
# 9.2                                          4.307582054690861
# 9.45                                          4.37065573786673
# 9.1                                          5.335827267779472
# 8.9                                          4.982865377312641
# 9.4                                         3.8371453204858317
#
# Mean number of stable clusters per patient         Range of features per cluster
# 4.75                                                                    1.6 2.88
# 7.05                                                                     2.0 3.6
# 7.75                                                                    2.25 4.0
# 8.45                                                      2.3225806451612905 4.5
# 9.2                                                       2.3225806451612905 4.8
# 9.45                                                       2.4 5.142857142857143
# 9.1                                                       2.4827586206896552 4.8
# 8.9                                         2.3225806451612905 5.142857142857143
# 9.4                                         2.6666666666666665 5.538461538461538

# %%
df_res[['Min clusters', 'Max clusters']] = df_res['Range of clusters'].str.split(expand=True)
#df_res['Min clusters'] = df_res['Range of clusters'].str.split(' ')[0]
#df_res['Max clusters'] = df_res['Range of clusters'].split(' ')[2]

df_res['Min clusters'] = df_res['Min clusters'].astype(int)
df_res['Max clusters'] = df_res['Max clusters'].astype(int)

df_res[['Min features', 'Max features']] = df_res['Range of features per cluster'].str.split(expand=True).astype(float)
df_res['Min features'] = df_res['Min features'].astype(float)
df_res['Max features'] = df_res['Max features'].astype(float)


df_res.rename(columns={'Mean number of clusters per patient': 'Mean clusters per patient'}, inplace=True)

df_res['Mean clusters per patient'] = df_res['Mean clusters per patient'].astype(float)


df_res.drop(columns=['Range of clusters', 'Range of features per cluster'], inplace=True)
# Out:
# c:\Users\b01297ar\Documents\ProstateMRL-local\ProstateMRL-Radiomics\envPR\lib\site-packages\pandas\core\frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# c:\Users\b01297ar\Documents\ProstateMRL-local\ProstateMRL-Radiomics\envPR\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# c:\Users\b01297ar\Documents\ProstateMRL-local\ProstateMRL-Radiomics\envPR\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\b01297ar\Documents\ProstateMRL-local\ProstateMRL-Radiomics\envPR\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == "__main__":
# c:\Users\b01297ar\Documents\ProstateMRL-local\ProstateMRL-Radiomics\envPR\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# c:\Users\b01297ar\Documents\ProstateMRL-local\ProstateMRL-Radiomics\envPR\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# c:\Users\b01297ar\Documents\ProstateMRL-local\ProstateMRL-Radiomics\envPR\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# c:\Users\b01297ar\Documents\ProstateMRL-local\ProstateMRL-Radiomics\envPR\lib\site-packages\pandas\core\frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df_res
# Out:
# Mean number of stable clusters per patient T-val  Mean clusters per patient  \
# 4.75                                         0.5                      35.75
# 7.05                                        0.75                      27.80
# 7.75                                         1.0                      25.15
# 8.45                                        1.25                      23.80
# 9.2                                          1.5                      20.35
# 9.45                                        1.75                      19.55
# 9.1                                          2.0                      20.95
# 8.9                                         2.25                      21.25
# 9.4                                          2.5                      19.25
#
# Mean number of stable clusters per patient Mean features per cluster per patient  \
# 4.75                                                          2.0601272664862695
# 7.05                                                            2.66260615471485
# 7.75                                                           2.972241565246967
# 8.45                                                           3.129117267384941
# 9.2                                                            3.674002305303501
# 9.45                                                           3.833822122150295
# 9.1                                                            3.636079137225182
# 8.9                                                             3.56069784002462
# 9.4                                                            3.882767846188899
#
# Mean number of stable clusters per patient Std features per cluster per patient  \
# 4.75                                                        0.32849236431103307
# 7.05                                                        0.46756874505081725
# 7.75                                                         0.5988744175233447
# 8.45                                                         0.5980229246407355
# 9.2                                                          0.6895504230737847
# 9.45                                                         0.7328435914942792
# 9.1                                                          0.8299138998177549
# 8.9                                                          0.7974961659386226
# 9.4                                                          0.7726262010239815
#
# Mean number of stable clusters per patient     Std of clusters  Min clusters  \
# 4.75                                         5.369259480451755            25
# 7.05                                         4.629425336623156            20
# 7.75                                         4.891184336183448            18
# 8.45                                         4.431941477857971            16
# 9.2                                          4.307582054690861            15
# 9.45                                          4.37065573786673            14
# 9.1                                          5.335827267779472            15
# 8.9                                          4.982865377312641            14
# 9.4                                         3.8371453204858317            13
#
# Mean number of stable clusters per patient  Max clusters  Min features  \
# 4.75                                                  45      1.600000
# 7.05                                                  36      2.000000
# 7.75                                                  32      2.250000
# 8.45                                                  31      2.322581
# 9.2                                                   31      2.322581
# 9.45                                                  30      2.400000
# 9.1                                                   29      2.482759
# 8.9                                                   31      2.322581
# 9.4                                                   27      2.666667
#
# Mean number of stable clusters per patient  Max features
# 4.75                                            2.880000
# 7.05                                            3.600000
# 7.75                                            4.000000
# 8.45                                            4.500000
# 9.2                                             4.800000
# 9.45                                            5.142857
# 9.1                                             4.800000
# 8.9                                             5.142857
# 9.4                                             5.538462

# %%
for col in df_res.columns:
    df_res[col] = df_res[col].astype(float)

df_res.reset_index(inplace=True)
df_res.rename(columns={'Mean number of stable clusters per patient': 'Mean stable clusters'}, inplace=True)
# Out:
# c:\Users\b01297ar\Documents\ProstateMRL-local\ProstateMRL-Radiomics\envPR\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\b01297ar\Documents\ProstateMRL-local\ProstateMRL-Radiomics\envPR\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df_res.dtypes
# Out:
# Mean number of stable clusters per patient
# index                                     object
# T-val                                    float64
# Mean clusters per patient                float64
# Mean features per cluster per patient    float64
# Std features per cluster per patient     float64
# Std of clusters                          float64
# Min clusters                             float64
# Max clusters                             float64
# Min features                             float64
# Max features                             float64
# dtype: object

# %%
df_res['index'] = df_res['index'].astype(float)
df_res.rename(columns={'index': 'Mean stable clusters'}, inplace=True)
# Out:
# c:\Users\b01297ar\Documents\ProstateMRL-local\ProstateMRL-Radiomics\envPR\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
# plot t-val vs 
sns.set_theme(style="whitegrid")
fig, ax = plt.subplots(figsize=(10, 6))
# scatterplot of t-val vs min clusters
sns.lineplot(data=df_res, x='T-val', y='Min clusters', linestyle='--', color='black')
sns.lineplot(data=df_res, x='T-val', y='Max clusters', linestyle='--', color='black', label='Min/Max')
# plot mean with sd as error bars
sns.lineplot(data=df_res, x='T-val', y='Mean clusters per patient', color='blue', label='Mean')
plt.fill_between(df_res['T-val'], df_res['Mean clusters per patient'] - df_res['Std of clusters'], df_res['Mean clusters per patient'] + df_res['Std of clusters'],
                color='blue', alpha=0.2, label='Std')
sns.lineplot(data=df_res, x='T-val', y='Mean stable clusters', color='red', label='Stable clusters')
plt.legend(fontsize='large')

plt.title('Number clusters per patient', fontsize='large')
plt.xlabel('T-val', fontsize='large')
plt.ylabel('Number of clusters', fontsize='large')
plt.tight_layout()
plt.savefig('./SubmissionVisuals/t-valSM/clusters-per-patient.png')

# %%
df_res
# Out:
# Mean number of stable clusters per patient  Mean stable clusters  T-val  \
# 0                                                           4.75   0.50
# 1                                                           7.05   0.75
# 2                                                           7.75   1.00
# 3                                                           8.45   1.25
# 4                                                           9.20   1.50
# 5                                                           9.45   1.75
# 6                                                           9.10   2.00
# 7                                                           8.90   2.25
# 8                                                           9.40   2.50
#
# Mean number of stable clusters per patient  Mean clusters per patient  \
# 0                                                               35.75
# 1                                                               27.80
# 2                                                               25.15
# 3                                                               23.80
# 4                                                               20.35
# 5                                                               19.55
# 6                                                               20.95
# 7                                                               21.25
# 8                                                               19.25
#
# Mean number of stable clusters per patient  Mean features per cluster per patient  \
# 0                                                                        2.060127
# 1                                                                        2.662606
# 2                                                                        2.972242
# 3                                                                        3.129117
# 4                                                                        3.674002
# 5                                                                        3.833822
# 6                                                                        3.636079
# 7                                                                        3.560698
# 8                                                                        3.882768
#
# Mean number of stable clusters per patient  Std features per cluster per patient  \
# 0                                                                       0.328492
# 1                                                                       0.467569
# 2                                                                       0.598874
# 3                                                                       0.598023
# 4                                                                       0.689550
# 5                                                                       0.732844
# 6                                                                       0.829914
# 7                                                                       0.797496
# 8                                                                       0.772626
#
# Mean number of stable clusters per patient  Std of clusters  Min clusters  \
# 0                                                  5.369259          25.0
# 1                                                  4.629425          20.0
# 2                                                  4.891184          18.0
# 3                                                  4.431941          16.0
# 4                                                  4.307582          15.0
# 5                                                  4.370656          14.0
# 6                                                  5.335827          15.0
# 7                                                  4.982865          14.0
# 8                                                  3.837145          13.0
#
# Mean number of stable clusters per patient  Max clusters  Min features  \
# 0                                                   45.0      1.600000
# 1                                                   36.0      2.000000
# 2                                                   32.0      2.250000
# 3                                                   31.0      2.322581
# 4                                                   31.0      2.322581
# 5                                                   30.0      2.400000
# 6                                                   29.0      2.482759
# 7                                                   31.0      2.322581
# 8                                                   27.0      2.666667
#
# Mean number of stable clusters per patient  Max features
# 0                                               2.880000
# 1                                               3.600000
# 2                                               4.000000
# 3                                               4.500000
# 4                                               4.800000
# 5                                               5.142857
# 6                                               4.800000
# 7                                               5.142857
# 8                                               5.538462

# %%
# repeat for number of features per cluster
fig, ax = plt.subplots(figsize=(10, 6))

sns.lineplot(data=df_res, x='T-val', y='Min features', linestyle='--', color='black')
sns.lineplot(data=df_res, x='T-val', y='Max features', linestyle='--', color='black', label='Min/Max')
# plot mean with sd as error bars
sns.lineplot(data=df_res, x='T-val', y='Mean features per cluster per patient', color='blue', label='Mean')
plt.fill_between(df_res['T-val'], df_res['Mean features per cluster per patient'] - df_res['Std features per cluster per patient'], df_res['Mean features per cluster per patient'] + df_res['Std features per cluster per patient'],
                color='blue', alpha=0.2, label='Std')
plt.legend(fontsize='large')

plt.title('Mean number features per cluster per patient', fontsize='large')
plt.xlabel('T-val', fontsize='large')
plt.ylabel('Number of features', fontsize='large')
plt.tight_layout()
plt.savefig('./SubmissionVisuals/t-valSM/features-per-cluster.png')

# %%
# plot t-val vs 
sns.set_theme(style="whitegrid")

# scatterplot of t-val vs min features
sns.scatterplot(data=df_res, x='T-val', y='Min features')
sns.scatterplot(data=df_res, x='T-val', y='Max features')
sns.scatterplot(data=df_res, x='T-val', y='Mean features per cluster')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13412\2983842334.py in <module>
#       5 sns.scatterplot(data=df_res, x='T-val', y='Min features')
#       6 sns.scatterplot(data=df_res, x='T-val', y='Max features')
# ----> 7 sns.scatterplot(data=df_res, x='T-val', y='Mean features per cluster')
#       8
#       9 plt.show()
#
# c:\Users\b01297ar\Documents\ProstateMRL-local\ProstateMRL-Radiomics\envPR\lib\site-packages\seaborn\relational.py in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     740
#     741     variables = _ScatterPlotter.get_semantics(locals())
# --> 742     p = _ScatterPlotter(data=data, variables=variables, legend=legend)
#     743
#     744     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#
# c:\Users\b01297ar\Documents\ProstateMRL-local\ProstateMRL-Radiomics\envPR\lib\site-packages\seaborn\relational.py in __init__(self, data, variables, legend)
#     536         )
#     537
# --> 538         super().__init__(data=data, variables=variables)
#     539
#     540         self.legend = legend
#
# c:\Users\b01297ar\Documents\ProstateMRL-local\ProstateMRL-Radiomics\envPR\lib\site-packages\seaborn\_oldcore.py in __init__(self, data, variables)
#     638         # information for numeric axes would be information about log scales.
#     639         self._var_ordered = {"x": False, "y": False}  # alt., used DefaultDict
# --> 640         self.assign_variables(data, variables)
#     641
#     642         for var, cls in self._semantic_mappings.items():
#
# c:\Users\b01297ar\Documents\ProstateMRL-local\ProstateMRL-Radiomics\envPR\lib\site-packages\seaborn\_oldcore.py in assign_variables(self, data, variables)
#     700             self.input_format = "long"
#     701             plot_data, variables = self._assign_variables_longform(
# --> 702                 data, **variables,
#     703             )
#     704
#
# c:\Users\b01297ar\Documents\ProstateMRL-local\ProstateMRL-Radiomics\envPR\lib\site-packages\seaborn\_oldcore.py in _assign_variables_longform(self, data, **kwargs)
#     936
#     937                 err = f"Could not interpret value `{val}` for parameter `{key}`"
# --> 938                 raise ValueError(err)
#     939
#     940             else:
#
# ValueError: Could not interpret value `Mean features per cluster` for parameter `y`
