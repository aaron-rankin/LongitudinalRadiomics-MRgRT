# %%
from Functions import delta_model as dm
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('C:\\Users\\b01297ar\\Documents\\ProstateMRL-local\\ProstateMRL-Radiomics\\Paper1-Release\\Output\\Submission-Delta\\CM\\CorrMatrix.csv')
df = df.drop(columns=['Unnamed: 0'])

df.values
# Out:
# array([[1.        , 0.20210765, 0.04738624, ..., 0.00376081, 0.0722076 ,
#         0.60248218],
#        [0.20210765, 1.        , 0.86907474, ..., 0.66139974, 0.39277663,
#         0.23325815],
#        [0.04738624, 0.86907474, 1.        , ..., 0.85112782, 0.46917293,
#         0.13984962],
#        ...,
#        [0.00376081, 0.66139974, 0.85112782, ..., 1.        , 0.57894737,
#         0.13233083],
#        [0.0722076 , 0.39277663, 0.46917293, ..., 0.57894737, 1.        ,
#         0.03909774],
#        [0.60248218, 0.23325815, 0.13984962, ..., 0.13233083, 0.03909774,
#         1.        ]])

# %%
# upper triangle
mask = np.zeros_like(df, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# plot
plt.figure(figsize=(10, 10))
sns.heatmap(df, mask=mask, cmap='coolwarm', vmin=0.8, vmax=1)
# Out:
# c:\Users\b01297ar\Documents\ProstateMRL-local\ProstateMRL-Radiomics\envPR\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# <AxesSubplot:>

# %%
# loop through features and if corr value is above 0.8, print the feature pair
fts_keep = []
fts_remove = []
for i in range(len(df.columns)):
    for j in range(i+1, len(df.columns)):
        if i != j:
            if df.iloc[i, j] >= 0.95:
                print('---------------------------------------')
                print(df.columns[i], df.columns[j], df.iloc[i, j])
                # get meean of each feature
                
                mean1 = np.mean(df[df.columns[i]])
                mean2 = np.mean(df[df.columns[j]])
                print(mean1, mean2)
                # keep lowest mean
                if mean1 < mean2:
                    fts_keep.append(df.columns[i])
                    fts_remove.append(df.columns[j])
                else:
                    fts_keep.append(df.columns[j])
                    fts_remove.append(df.columns[i])

# remove duplicates
fts_keep = list(set(fts_keep))
fts_remove = list(set(fts_remove))

print(fts_keep)
print(fts_remove)

# remove features from fts_keep
for ft in fts_remove:
    if ft in fts_keep:
        fts_keep.remove(ft)

print(fts_keep)
print(len(fts_keep))
# Out:
# ---------------------------------------
# firstorder_10Percentile gldm_LargeDependenceHighGrayLevelEmphasis 0.954494238241328
# 0.3211204473119134 0.35881452829041577
# ---------------------------------------
# firstorder_10Percentile glrlm_LongRunHighGrayLevelEmphasis 0.954494238241328
# 0.3211204473119134 0.31172383866424896
# ---------------------------------------
# firstorder_90Percentile glrlm_HighGrayLevelRunEmphasis 0.9653877826944112
# 0.6404934334621396 0.6201067418136464
# ---------------------------------------
# firstorder_90Percentile glrlm_ShortRunHighGrayLevelEmphasis 0.9646353370336984
# 0.6404934334621396 0.6578198546694877
# ---------------------------------------
# firstorder_Entropy glcm_DifferenceEntropy 0.9518796992481202
# 0.6876416751115568 0.6688038384111906
# ---------------------------------------
# firstorder_Entropy glcm_JointEntropy 0.9909774436090224
# 0.6876416751115568 0.6884868200382241
# ---------------------------------------
# firstorder_Entropy glcm_SumEntropy 0.9864661654135336
# 0.6876416751115568 0.6776984016089823
# ---------------------------------------
# firstorder_Entropy glrlm_GrayLevelNonUniformityNormalized 0.9699248120300752
# 0.6876416751115568 0.6608343474051488
# ---------------------------------------
# firstorder_InterquartileRange firstorder_RobustMeanAbsoluteDeviation 0.9924553128728038
# 0.5772127106199373 0.5683727018349153
# ---------------------------------------
# firstorder_Mean glcm_Autocorrelation 0.9563909774436089
# 0.5110429825706713 0.5662035456760475
# ---------------------------------------
# firstorder_Mean glcm_JointAverage 1.0
# 0.5110429825706713 0.5110429825706713
# ---------------------------------------
# firstorder_Mean glcm_SumAverage 1.0
# 0.5110429825706713 0.5110429825706713
# ---------------------------------------
# firstorder_MeanAbsoluteDeviation firstorder_Variance 0.9669172932330824
# 0.6427806212396686 0.6558552086944323
# ---------------------------------------
# firstorder_MeanAbsoluteDeviation glcm_ClusterTendency 0.9744360902255638
# 0.6427806212396686 0.6457244482325671
# ---------------------------------------
# firstorder_MeanAbsoluteDeviation glcm_SumSquares 0.9729323308270676
# 0.6427806212396686 0.6489234698747286
# ---------------------------------------
# firstorder_MeanAbsoluteDeviation gldm_GrayLevelVariance 0.9624060150375938
# 0.6427806212396686 0.6588390049942808
# ---------------------------------------
# firstorder_MeanAbsoluteDeviation glrlm_GrayLevelVariance 0.9533834586466164
# 0.6427806212396686 0.6582884475039855
# ---------------------------------------
# firstorder_Median glrlm_LowGrayLevelRunEmphasis 0.96835213548654
# 0.34204780194183604 0.3850272911696206
# ---------------------------------------
# firstorder_RootMeanSquared glcm_Autocorrelation 0.9563909774436089
# 0.6187553037365366 0.5662035456760475
# ---------------------------------------
# firstorder_RootMeanSquared gldm_HighGrayLevelEmphasis 0.9804511278195488
# 0.6187553037365366 0.5872101340159016
# ---------------------------------------
# firstorder_RootMeanSquared glrlm_HighGrayLevelRunEmphasis 0.9714285714285714
# 0.6187553037365366 0.6201067418136464
# ---------------------------------------
# firstorder_Uniformity glcm_JointEnergy 0.9744360902255638
# 0.6322950806293878 0.6014930296905541
# ---------------------------------------
# firstorder_Uniformity gldm_DependenceEntropy 0.9518796992481202
# 0.6322950806293878 0.6429178013922646
# ---------------------------------------
# firstorder_Uniformity glrlm_GrayLevelNonUniformityNormalized 0.9578947368421054
# 0.6322950806293878 0.6608343474051488
# ---------------------------------------
# firstorder_Variance glcm_ClusterTendency 0.993984962406015
# 0.6558552086944323 0.6457244482325671
# ---------------------------------------
# firstorder_Variance glcm_SumSquares 0.9924812030075189
# 0.6558552086944323 0.6489234698747286
# ---------------------------------------
# firstorder_Variance gldm_GrayLevelVariance 0.9969924812030074
# 0.6558552086944323 0.6588390049942808
# ---------------------------------------
# firstorder_Variance glrlm_GrayLevelVariance 0.9909774436090224
# 0.6558552086944323 0.6582884475039855
# ---------------------------------------
# glcm_Autocorrelation glcm_JointAverage 0.9563909774436089
# 0.5662035456760475 0.5110429825706713
# ---------------------------------------
# glcm_Autocorrelation glcm_SumAverage 0.9563909774436089
# 0.5662035456760475 0.5110429825706713
# ---------------------------------------
# glcm_Autocorrelation gldm_HighGrayLevelEmphasis 0.9924812030075189
# 0.5662035456760475 0.5872101340159016
# ---------------------------------------
# glcm_Autocorrelation glrlm_HighGrayLevelRunEmphasis 0.9639097744360902
# 0.5662035456760475 0.6201067418136464
# ---------------------------------------
# glcm_ClusterTendency glcm_SumSquares 0.9984962406015038
# 0.6457244482325671 0.6489234698747286
# ---------------------------------------
# glcm_ClusterTendency gldm_GrayLevelVariance 0.9909774436090224
# 0.6457244482325671 0.6588390049942808
# ---------------------------------------
# glcm_ClusterTendency glrlm_GrayLevelVariance 0.9804511278195488
# 0.6457244482325671 0.6582884475039855
# ---------------------------------------
# glcm_Contrast glcm_DifferenceAverage 0.9669172932330824
# 0.6334110118757599 0.6539184135145296
# ---------------------------------------
# glcm_Contrast glcm_DifferenceEntropy 0.9639097744360902
# 0.6334110118757599 0.6688038384111906
# ---------------------------------------
# glcm_Contrast glcm_DifferenceVariance 0.9819548872180448
# 0.6334110118757599 0.6202992577440616
# ---------------------------------------
# glcm_Contrast gldm_SmallDependenceEmphasis 0.9518796992481202
# 0.6334110118757599 0.6595844058873662
# ---------------------------------------
# glcm_Contrast gldm_SmallDependenceHighGrayLevelEmphasis 0.9578947368421054
# 0.6334110118757599 0.6453570705386413
# ---------------------------------------
# glcm_DifferenceAverage glcm_DifferenceEntropy 0.9864661654135336
# 0.6539184135145296 0.6688038384111906
# ---------------------------------------
# glcm_DifferenceAverage glcm_Id 0.9849624060150376
# 0.6539184135145296 0.6543454760105581
# ---------------------------------------
# glcm_DifferenceAverage glcm_Idm 0.9894736842105262
# 0.6539184135145296 0.6587877724516984
# ---------------------------------------
# glcm_DifferenceAverage glrlm_RunLengthNonUniformityNormalized 0.9699248120300752
# 0.6539184135145296 0.6569627945390576
# ---------------------------------------
# glcm_DifferenceAverage glrlm_RunPercentage 0.9684210526315788
# 0.6539184135145296 0.647862100757244
# ---------------------------------------
# glcm_DifferenceAverage glrlm_ShortRunEmphasis 0.9624060150375938
# 0.6539184135145296 0.6639334477368687
# ---------------------------------------
# glcm_DifferenceEntropy glcm_Id 0.9654135338345864
# 0.6688038384111906 0.6543454760105581
# ---------------------------------------
# glcm_DifferenceEntropy glcm_Idm 0.9729323308270676
# 0.6688038384111906 0.6587877724516984
# ---------------------------------------
# glcm_DifferenceEntropy glcm_JointEntropy 0.950375939849624
# 0.6688038384111906 0.6884868200382241
# ---------------------------------------
# glcm_DifferenceEntropy gldm_GrayLevelVariance 0.9518796992481202
# 0.6688038384111906 0.6588390049942808
# ---------------------------------------
# glcm_DifferenceEntropy gldm_SmallDependenceEmphasis 0.9563909774436089
# 0.6688038384111906 0.6595844058873662
# ---------------------------------------
# glcm_DifferenceEntropy glrlm_RunLengthNonUniformityNormalized 0.9593984962406013
# 0.6688038384111906 0.6569627945390576
# ---------------------------------------
# glcm_DifferenceEntropy glrlm_ShortRunEmphasis 0.9669172932330824
# 0.6688038384111906 0.6639334477368687
# ---------------------------------------
# glcm_Id glcm_Idm 0.9969924812030074
# 0.6543454760105581 0.6587877724516984
# ---------------------------------------
# glcm_Id gldm_LargeDependenceEmphasis 0.9624060150375938
# 0.6543454760105581 0.6257547538658927
# ---------------------------------------
# glcm_Id glrlm_RunLengthNonUniformityNormalized 0.9834586466165413
# 0.6543454760105581 0.6569627945390576
# ---------------------------------------
# glcm_Id glrlm_RunPercentage 0.9909774436090224
# 0.6543454760105581 0.647862100757244
# ---------------------------------------
# glcm_Id glrlm_ShortRunEmphasis 0.9669172932330824
# 0.6543454760105581 0.6639334477368687
# ---------------------------------------
# glcm_Idm glcm_JointEntropy 0.950375939849624
# 0.6587877724516984 0.6884868200382241
# ---------------------------------------
# glcm_Idm gldm_LargeDependenceEmphasis 0.9563909774436089
# 0.6587877724516984 0.6257547538658927
# ---------------------------------------
# glcm_Idm glrlm_RunLengthNonUniformityNormalized 0.9834586466165413
# 0.6587877724516984 0.6569627945390576
# ---------------------------------------
# glcm_Idm glrlm_RunPercentage 0.9864661654135336
# 0.6587877724516984 0.647862100757244
# ---------------------------------------
# glcm_Idm glrlm_ShortRunEmphasis 0.9654135338345864
# 0.6587877724516984 0.6639334477368687
# ---------------------------------------
# glcm_Idmn glcm_Idn 0.9639097744360902
# 0.2448730563612285 0.23239646354323476
# ---------------------------------------
# glcm_JointAverage glcm_SumAverage 1.0
# 0.5110429825706713 0.5110429825706713
# ---------------------------------------
# glcm_JointEntropy glcm_SumEntropy 0.9894736842105262
# 0.6884868200382241 0.6776984016089823
# ---------------------------------------
# glcm_JointEntropy glrlm_GrayLevelNonUniformityNormalized 0.9518796992481202
# 0.6884868200382241 0.6608343474051488
# ---------------------------------------
# glcm_SumEntropy glrlm_GrayLevelNonUniformityNormalized 0.9593984962406013
# 0.6776984016089823 0.6608343474051488
# ---------------------------------------
# glcm_SumSquares gldm_GrayLevelVariance 0.9894736842105262
# 0.6489234698747286 0.6588390049942808
# ---------------------------------------
# glcm_SumSquares glrlm_GrayLevelVariance 0.9774436090225564
# 0.6489234698747286 0.6582884475039855
# ---------------------------------------
# gldm_DependenceEntropy glrlm_GrayLevelNonUniformityNormalized 0.9684210526315788
# 0.6429178013922646 0.6608343474051488
# ---------------------------------------
# gldm_GrayLevelVariance glrlm_GrayLevelVariance 0.9909774436090224
# 0.6588390049942808 0.6582884475039855
# ---------------------------------------
# gldm_HighGrayLevelEmphasis glrlm_HighGrayLevelRunEmphasis 0.9774436090225564
# 0.5872101340159016 0.6201067418136464
# ---------------------------------------
# gldm_LargeDependenceEmphasis glrlm_RunLengthNonUniformityNormalized 0.950375939849624
# 0.6257547538658927 0.6569627945390576
# ---------------------------------------
# gldm_LargeDependenceEmphasis glrlm_RunPercentage 0.9804511278195488
# 0.6257547538658927 0.647862100757244
# ---------------------------------------
# gldm_LargeDependenceLowGrayLevelEmphasis glrlm_LongRunLowGrayLevelEmphasis 0.9894736842105262
# 0.4258345518057843 0.4814707425573755
# ---------------------------------------
# gldm_LowGrayLevelEmphasis glrlm_LowGrayLevelRunEmphasis 0.9518796992481202
# 0.3654953228909932 0.3850272911696206
# ---------------------------------------
# gldm_SmallDependenceEmphasis gldm_SmallDependenceHighGrayLevelEmphasis 0.9819548872180448
# 0.6595844058873662 0.6453570705386413
# ---------------------------------------
# glrlm_HighGrayLevelRunEmphasis glrlm_ShortRunHighGrayLevelEmphasis 0.9563909774436089
# 0.6201067418136464 0.6578198546694877
# ---------------------------------------
# glrlm_LongRunEmphasis glrlm_RunVariance 0.9669172932330824
# 0.590825502403406 0.5392253786866253
# ---------------------------------------
# glrlm_RunLengthNonUniformityNormalized glrlm_RunPercentage 0.9804511278195488
# 0.6569627945390576 0.647862100757244
# ---------------------------------------
# glrlm_RunLengthNonUniformityNormalized glrlm_ShortRunEmphasis 0.9894736842105262
# 0.6569627945390576 0.6639334477368687
# ---------------------------------------
# glrlm_RunPercentage glrlm_ShortRunEmphasis 0.9669172932330824
# 0.647862100757244 0.6639334477368687
# ['glcm_DifferenceAverage', 'glcm_DifferenceEntropy', 'glrlm_ShortRunEmphasis', 'gldm_LowGrayLevelEmphasis', 'firstorder_RobustMeanAbsoluteDeviation', 'glcm_Idm', 'glcm_SumAverage', 'gldm_SmallDependenceHighGrayLevelEmphasis', 'glcm_Id', 'firstorder_Uniformity', 'gldm_LargeDependenceLowGrayLevelEmphasis', 'glcm_Contrast', 'glcm_SumEntropy', 'gldm_LargeDependenceEmphasis', 'firstorder_Median', 'glcm_JointEnergy', 'firstorder_MeanAbsoluteDeviation', 'glrlm_RunPercentage', 'firstorder_Variance', 'glcm_ClusterTendency', 'firstorder_90Percentile', 'gldm_DependenceEntropy', 'gldm_GrayLevelVariance', 'glrlm_RunVariance', 'glcm_Autocorrelation', 'glrlm_RunLengthNonUniformityNormalized', 'firstorder_10Percentile', 'gldm_HighGrayLevelEmphasis', 'firstorder_RootMeanSquared', 'glcm_JointAverage', 'gldm_SmallDependenceEmphasis', 'glcm_Idn', 'glrlm_HighGrayLevelRunEmphasis', 'glrlm_LongRunHighGrayLevelEmphasis', 'glcm_SumSquares', 'glrlm_GrayLevelNonUniformityNormalized', 'firstorder_Mean', 'glrlm_GrayLevelVariance', 'firstorder_Entropy', 'glcm_DifferenceVariance']
# ['glcm_DifferenceAverage', 'gldm_LargeDependenceHighGrayLevelEmphasis', 'glcm_DifferenceEntropy', 'glrlm_ShortRunEmphasis', 'glcm_Idm', 'gldm_SmallDependenceHighGrayLevelEmphasis', 'glcm_Id', 'firstorder_Uniformity', 'glcm_Contrast', 'glcm_SumEntropy', 'glrlm_LongRunEmphasis', 'glrlm_RunPercentage', 'glrlm_ShortRunHighGrayLevelEmphasis', 'firstorder_Variance', 'glcm_ClusterTendency', 'firstorder_90Percentile', 'gldm_DependenceEntropy', 'gldm_GrayLevelVariance', 'glcm_Idmn', 'firstorder_InterquartileRange', 'glcm_Autocorrelation', 'glrlm_RunLengthNonUniformityNormalized', 'firstorder_10Percentile', 'firstorder_RootMeanSquared', 'gldm_HighGrayLevelEmphasis', 'glcm_JointAverage', 'gldm_SmallDependenceEmphasis', 'glrlm_HighGrayLevelRunEmphasis', 'glcm_SumSquares', 'glrlm_GrayLevelNonUniformityNormalized', 'firstorder_Mean', 'glrlm_LowGrayLevelRunEmphasis', 'glrlm_GrayLevelVariance', 'glrlm_LongRunLowGrayLevelEmphasis', 'firstorder_Entropy', 'glcm_JointEntropy']
# ['gldm_LowGrayLevelEmphasis', 'firstorder_RobustMeanAbsoluteDeviation', 'glcm_SumAverage', 'gldm_LargeDependenceLowGrayLevelEmphasis', 'gldm_LargeDependenceEmphasis', 'firstorder_Median', 'glcm_JointEnergy', 'firstorder_MeanAbsoluteDeviation', 'glrlm_RunVariance', 'glcm_Idn', 'glrlm_LongRunHighGrayLevelEmphasis', 'glcm_DifferenceVariance']
# 12

# %%
df_keep_delta = pd.DataFrame(fts_keep, columns=['Feature'])

df_keep_lng = pd.read_csv('C:\\Users\\b01297ar\\Documents\\ProstateMRL-local\\ProstateMRL-Radiomics\\Paper1-Release\\Output\\Sensitivity\\Run-1.75\\features\\Features_Selected.csv')

fts_del = df_keep_delta['Feature'].values
fts_lng = df_keep_lng['Feature'].values

# check if all features are in the long list
for ft in fts_del:
    if ft not in fts_lng:
        print('Not in both', ft)
    
    else:
        print('In both', ft)
# Out:
# Not in both gldm_LowGrayLevelEmphasis
# Not in both firstorder_RobustMeanAbsoluteDeviation
# Not in both glcm_SumAverage
# Not in both gldm_LargeDependenceLowGrayLevelEmphasis
# Not in both gldm_LargeDependenceEmphasis
# In both firstorder_Median
# In both glcm_JointEnergy
# Not in both firstorder_MeanAbsoluteDeviation
# Not in both glrlm_RunVariance
# Not in both glcm_Idn
# Not in both glrlm_LongRunHighGrayLevelEmphasis
# Not in both glcm_DifferenceVariance
